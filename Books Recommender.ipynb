# %%
import numpy as np
import pandas as pd
from slugify import slugify

# %%
books=pd.read_csv("books.csv")
users=pd.read_csv("users.csv")
ratings=pd.read_csv("ratings.csv")
# Out:
# C:\Users\mrcha\AppData\Local\Temp\ipykernel_30408\2573390583.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
#slugify(books['Book-Title'][0])

def generateSlug(title):
    return slugify(title)

books['Book-Slug'] = books['Book-Title'].apply(lambda x :generateSlug(x))

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books[books['Book-Slug'] == "shella"].drop_duplicates('Book-Slug')['Book-Title'].values[0]
# What's a Christian to Do with Harry Potter?
# books[books['Book-Title'] == "What's a Christian to Do with Harry Potter?"].drop_duplicates('Book-Title')['Book-Title']
# books[books['Book-Title'] == "The Black Echo (Detective Harry Bosch Mysteries)"].drop_duplicates('Book-Title')['Book-Slug']
# Out:
# 'Shella'

# %%
books[books['Book-Slug'] == "harry-potter-and-the-prisoner-of-azkaban-book-3"].drop_duplicates('Book-Slug').index[0]
# Out:
# 3839

# %%
books.count()
# Out:
# ISBN                   271360
# Book-Title             271360
# Book-Author            271359
# Year-Of-Publication    271360
# Publisher              271358
# Image-URL-S            271360
# Image-URL-M            271360
# Image-URL-L            271357
# Book-Slug              271360
# dtype: int64

# %%
#books[books['Book-Title'].str.contains("4839hgf8e67", na=False, case=False)].drop_duplicates('Book-Title')

# %%
books[books["Book-Title"].isin(["Harry"])]
# Out:
# Empty DataFrame
# Columns: [ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher, Image-URL-S, Image-URL-M, Image-URL-L, Book-Slug]
# Index: []

# %%
books["Image-URL-L"].isnull().sum()
# Out:
# 3

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings[ratings["User-ID"].isin([3839])]
# Out:
#        User-ID        ISBN  Book-Rating
# 20425     3839  0060932759            7
# 20426     3839  0312171838            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 9)
# (278858, 3)
# (1149780, 3)

# %% [markdown]
# ## Check is Null Value or not

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# Book-Slug              0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %% [markdown]
# ## Check is Duplicated Value or not

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommedation System

# %% [markdown]
# <p>Display Books on Highest Rating and Minimum rating count >=250 </p>

# %% [markdown]
# ## Merge Two Tables

# %%
ratings.merge(books,on='ISBN')
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
ratings.merge(books,on='ISBN').shape
# Out:
# (1031136, 11)

# %%
#ratings[ratings["Book-Title"].isin(["Harry Potter and the Prisoner of Azkaban (Book 3)"])]

# %%
ratings_with_name=ratings.merge(books,on='ISBN')
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df=ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_ratings'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df=num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
popular_df=popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %% [markdown]
# ## Merge for Required Data for AUthor , Image URL  or etc

# %%
popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Image-URL-L','num_ratings','avg_ratings','Year-Of-Publication','Book-Slug']]
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
popular_df['Image-URL-L']
# Out:
# 0      http://images.amazon.com/images/P/0439136350.0...
# 3      http://images.amazon.com/images/P/0439139597.0...
# 5      http://images.amazon.com/images/P/0590353403.0...
# 9      http://images.amazon.com/images/P/043935806X.0...
# 13     http://images.amazon.com/images/P/0439064872.0...
# 16     http://images.amazon.com/images/P/0345339681.0...
# 17     http://images.amazon.com/images/P/0345339703.0...
# 26     http://images.amazon.com/images/P/059035342X.0...
# 28     http://images.amazon.com/images/P/0345339711.0...
# 39     http://images.amazon.com/images/P/0446310786.0...
# 47     http://images.amazon.com/images/P/0385504209.0...
# 53     http://images.amazon.com/images/P/0786868716.0...
# 55     http://images.amazon.com/images/P/0316769487.0...
# 62     http://images.amazon.com/images/P/0316666343.0...
# 63     http://images.amazon.com/images/P/0451524934.0...
# 72     http://images.amazon.com/images/P/0060959037.0...
# ...

# %% [markdown]
# # Collbarting Filtering Based Recommdation System

# %% [markdown]
# <p> User Has Minimum 200 Books Ratings and also Books has minimum 50 Ratings on this Book </p>

# %% [markdown]
# ### Get User count

# %%
x=ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
experience_user=x[x].index

# %%
fitered_rating= ratings_with_name[ratings_with_name['User-ID'].isin(experience_user)]

# %%
fitered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %% [markdown]
# #### Books Logic >50

# %%
y=fitered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
fitered_rating['Book-Title'].isin(famous_books)
# Out:
# 2          False
# 5          False
# 7          False
# 15         False
# 16         False
#            ...
# 1030883    False
# 1030884    False
# 1030885    False
# 1030886    False
# 1030887    False
# Name: Book-Title, Length: 474007, dtype: bool

# %%
fitered_rating[fitered_rating['Book-Title'].isin(famous_books)]
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings= fitered_rating[fitered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %% [markdown]
# #### Pivot table x= User ,Y= Book Name  and Value= Ratings

# %%
final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.shape
# Out:
# (706, 810)

# %% [markdown]
# #### Replace NaN to 0.0 for rating

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
np.where(pt.index=="Harry Potter and the Goblet of Fire (Book 4)")[0][0]
# Out:
# 228

# %% [markdown]
# #### find Distance between all vector using cosine similarity

# %% [markdown]
# <p> Install Sklearn Command : <code> pip3 install -U scikit-learn scipy matplotlib </code></p>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(pt)
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
cosine_similarity(pt).shape
# Out:
# (706, 706)

# %%
similarity_score= cosine_similarity(pt)

# %%
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %% [markdown]
# <p>Find Index of Book using <code>np.where(pt.index=='1984')</code></p>

# %%
np.where(pt.index=='Zoya')[0][0]
# Out:
# 704

# %% [markdown]
# #### Find similarity book using Index of Book

# %%
similarity_score[704]
# Out:
# array([0.07347567, 0.16773875, 0.04938579, 0.        , 0.11284126,
#        0.11224972, 0.1536172 , 0.07070243, 0.13194105, 0.0879174 ,
#        0.09394598, 0.        , 0.0722577 , 0.08751563, 0.19013896,
#        0.08838835, 0.13847624, 0.0493197 , 0.10184887, 0.06381997,
#        0.12381007, 0.        , 0.12535646, 0.08885599, 0.13360872,
#        0.        , 0.05969674, 0.06236096, 0.16039401, 0.06786258,
#        0.03106883, 0.05959444, 0.        , 0.30199543, 0.        ,
#        0.14389473, 0.04492721, 0.22358045, 0.10559799, 0.19520018,
#        0.        , 0.0803096 , 0.03598302, 0.04895763, 0.05785163,
#        0.17427718, 0.        , 0.07634573, 0.09451121, 0.11624778,
#        0.09408918, 0.10399847, 0.        , 0.10328147, 0.0777027 ,
#        0.        , 0.1270828 , 0.02257064, 0.13786105, 0.05758289,
#        0.07193131, 0.        , 0.05018676, 0.32252503, 0.        ,
#        0.0840875 , 0.07884165, 0.        , 0.10081854, 0.02776016,
# ...

# %%
list(enumerate(similarity_score[704]))
# Out:
# [(0, 0.07347566833900478),
#  (1, 0.16773874700966604),
#  (2, 0.049385791533561194),
#  (3, 0.0),
#  (4, 0.11284126193916974),
#  (5, 0.11224972160321824),
#  (6, 0.15361720202716334),
#  (7, 0.07070243341762764),
#  (8, 0.1319410475877449),
#  (9, 0.08791739645277159),
#  (10, 0.09394597981669818),
#  (11, 0.0),
#  (12, 0.07225769692096456),
#  (13, 0.08751562918651386),
#  (14, 0.1901389647343182),
#  (15, 0.08838834764831843),
#  (16, 0.13847623672431844),
#  (17, 0.049319696191607185),
#  (18, 0.10184887337581867),
#  (19, 0.06381996508895696),
#  (20, 0.12381006971050557),
#  (21, 0.0),
#  (22, 0.12535646060197012),
#  (23, 0.08885598535680138),
#  (24, 0.13360872291251571),
#  (25, 0.0),
#  (26, 0.05969674327970392),
#  (27, 0.06236095644623235),
#  (28, 0.1603940145729817),
#  (29, 0.06786258395299352),
#  (30, 0.03106883103588355),
#  (31, 0.05959443516119297),
#  (32, 0.0),
#  (33, 0.30199542705413734),
#  (34, 0.0),
#  (35, 0.14389472555751187),
# ...

# %%
sorted(list(enumerate(similarity_score[704])),key=lambda x:x[1],reverse=True)[1:6]
# Out:
# [(194, 0.6188332046777836),
#  (424, 0.5423917439488084),
#  (288, 0.4536936187776783),
#  (175, 0.43416881684252095),
#  (196, 0.43104197190280946)]

# %%
def recommend(book_name):
    # Fetch Index
    index= np.where(pt.index==book_name)[0][0]
    similar_items= sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:11]
    data= [] 
    for i in similar_items:
        #print(i[0])
        #print(pt.index[i[0]])
        item = []
        temp_df=books[books['Book-Title'] == pt.index[i[0]]]
        #item.append(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values)) // 2d list
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Year-Of-Publication'].values))
        data.append(item)
        return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg',
#   2004]]

# %%
def getBookDetail(book_name):
    # Fetch Book Detail from Book Name
    books_details = [] 
    book_items= []
    book_items.extend(list(books[books['Book-Title'] == book_name].drop_duplicates('Book-Title')['Book-Title'].values))
    book_items.extend(list(books[books['Book-Title'] == book_name].drop_duplicates('Book-Title')['Book-Author'].values))
    book_items.extend(list(books[books['Book-Title'] == book_name].drop_duplicates('Book-Title')['Image-URL-M'].values))
    book_items.extend(list(books[books['Book-Title'] == book_name].drop_duplicates('Book-Title')['Year-Of-Publication'].values))
    books_details.append(book_items)
    return books_details

# %%
getBookDetail('Animal Farm')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg',
#   2004]]

# %% [markdown]
# ## Export Popular Books using Pickle

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))
